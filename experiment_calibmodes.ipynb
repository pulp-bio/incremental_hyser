# %%
import itertools
import pickle
from pathlib import Path

import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

import ztbiocas.datasets.uniboinail as ui
import ztbiocas.learning.mlpuniboinail as mui
import ztbiocas.learning.learning as learn
from ztbiocas import protocol

# %%
NUM_REPETITIONS = 1

DOWNSAMPLING_FACTOR = 100  # 10 # 1

NUM_CALIB_REPETITIONS = 5

NUM_EPOCHS_FP = 4

RESULTS_FILENAME = 'results_refit_replication.pkl'
RESULTS_DIR_PATH = './results/'
RESULTS_FILE_FULLPATH = RESULTS_DIR_PATH + RESULTS_FILENAME

# %%
# structure for storing the results

results = {
    'num_repetitions': NUM_REPETITIONS,
    'repetition': {},
}

for idx_rep in range(NUM_REPETITIONS):
    results['repetition'][idx_rep] = {'subject': {}}

    for idx_subject in range(ui.NUM_SUBJECTS):

        results['repetition'][idx_rep]['subject'][idx_subject] = {'day': {}}

        for idx_day in range(ui.NUM_DAYS):

            results['repetition'][idx_rep]['subject'][idx_subject]['day'][idx_day] = {'reference_posture': {}}

            for idx_ref_posture in range(ui.NUM_POSTURES):

                results['repetition'][idx_rep]['subject'][idx_subject]['day'][idx_day]['reference_posture'][idx_ref_posture] = {'target_posture': {}}

                for idx_tgt_posture in range(ui.NUM_POSTURES):

                    results['repetition'][idx_rep]['subject'][idx_subject]['day'][idx_day]['reference_posture'][idx_ref_posture]['target_posture'][idx_tgt_posture] = {
                        'calibration': {
                            'frozen': {},
                            'refit': {},
                        },
                        'validation': {
                            'frozen': {},
                            'refit': {},
                        },
                    }

# %%
for idx_repetition, idx_subject, idx_day, idx_ref_posture in itertools.product(
    range(NUM_REPETITIONS),
    range(ui.NUM_SUBJECTS),
    range(ui.NUM_DAYS),
    range(ui.NUM_POSTURES)
):
    
    # ----------------------------------------------------------------------- #

    # print a header
    print(
        f"\n"
        f"------------------------------------------------------------------\n"
        f"REPETITION\t{idx_repetition + 1 :d}/{NUM_REPETITIONS:d}\n"
        f"SUBJECT\t{idx_subject + 1 :d}/{ui.NUM_SUBJECTS:d}\n"
        f"DAY\t{idx_day + 1 :d}/{ui.NUM_DAYS:d}\n"
        f"POSTURE\t{idx_ref_posture + 1 :d}/{ui.NUM_POSTURES:d} AS REFERENCE\n"
        f"(all indices are one-based)\n"
        f"------------------------------------------------------------------\n"
        f"\n"
    )

    # ----------------------------------------------------------------------- #

    # load training data
    train_session_data_dict = ui.load_session(
        idx_subject, idx_day, idx_ref_posture)
    xtrain = train_session_data_dict['emg']
    ytrain = train_session_data_dict['relabel']
    del train_session_data_dict

    # ----------------------------------------------------------------------- #

    # downsampling
    xtrain = xtrain[:, ::DOWNSAMPLING_FACTOR]
    ytrain = ytrain[::DOWNSAMPLING_FACTOR]

    # standard scaling and de-correlation, as preprocessing before training
    stdscaler_train = StandardScaler()
    xtrain_stdscaled = stdscaler_train.fit_transform(xtrain.T).T
    del xtrain
    pca_train = PCA(n_components=ui.NUM_CHANNELS, whiten=False)
    xtrain_pc = pca_train.fit_transform(xtrain_stdscaled.T).T
    del xtrain_stdscaled

    # ----------------------------------------------------------------------- #

    # MLP training and validation

    mlp = mui.MLPUniboINAIL(num_input=ui.NUM_CHANNELS, num_hidden=8, num_output=ui.NUM_CLASSES)
    mui.summarize(mlp, num_input=ui.NUM_CHANNELS)

    # full-precision training
    mlp, history, yout_train, yout_valid = learn.do_training(
        xtrain=xtrain_pc,
        ytrain=ytrain,
        model=mlp,
        xvalid=None,
        yvalid=None,
        num_epochs=NUM_EPOCHS_FP,
        mltask=learn.MLTask.CLASSIFICATION,
        num_classes=ui.NUM_CLASSES,
    )

    # ----------------------------------------------------------------------- #

    # "tgt posture" stands for "target posture"
    for idx_tgt_posture in range(ui.NUM_POSTURES):

        # ------------------------------------------------------------------- #

        # print a header
        print(
            f"\n"
            f"--------------------------------------------------------------\n"
            f"TARGET POSTURE {idx_tgt_posture + 1 :d}\n"
            f"(trained on {idx_ref_posture + 1 :d})\n"
            f"--------------------------------------------------------------\n"
            f"\n"
        )

        # ------------------------------------------------------------------- #
        # ------------------------------------------------------------------- #

        # Do the two experiments:
        # - no adaptation
        # - refit the PCA online

        # ------------------------------------------------------------------- #
        # ------------------------------------------------------------------- #

        # load calibration and validation data

        calibvalid_session_data_dict = ui.load_session(
            idx_subject, idx_day, idx_tgt_posture)

        emg_calibvalid = calibvalid_session_data_dict['emg']
        relabel_calibvalid = calibvalid_session_data_dict['relabel']
        gesture_counter_calibvalid = \
            calibvalid_session_data_dict['gesture_counter']
        del calibvalid_session_data_dict

        xcalib, ycalib, xvalid, yvalid = ui.split_into_calib_and_valid(
            emg=emg_calibvalid,
            relabel=relabel_calibvalid,
            gesture_counter=gesture_counter_calibvalid,
            num_calib_repetitions=NUM_CALIB_REPETITIONS,
        )
        del emg_calibvalid, relabel_calibvalid, gesture_counter_calibvalid

        # ------------------------------------------------------------------- #

        # downsampling
        # NB: frozen standard scaling is included in the function
        # calibration_experiment
        xcalib = xcalib[:, ::DOWNSAMPLING_FACTOR]
        xvalid = xvalid[:, ::DOWNSAMPLING_FACTOR]
        ycalib = ycalib[::DOWNSAMPLING_FACTOR]
        yvalid = yvalid[::DOWNSAMPLING_FACTOR]
        
        # ------------------------------------------------------------------- #

        metrics = protocol.calibration_experiment(
            xcalib=xcalib,
            ycalib=ycalib,
            xvalid=xvalid,
            yvalid=yvalid,
            beta=0.01,
            stdscaler_train=stdscaler_train,
            pca_train=pca_train,
            model=mlp,
        )
        
        print('VALIDATION METRICS')
        print('unbalanced')
        print(metrics['validation']['frozen']['accuracy'])
        print(metrics['validation']['refit']['accuracy'])
        print('balanced')
        print(metrics['validation']['frozen']['balanced_accuracy'])
        print(metrics['validation']['refit']['balanced_accuracy'])

        # store results
        results['repetition'][idx_repetition]['subject'][idx_subject]['day'][idx_day]['reference_posture'][idx_ref_posture][
            'target_posture'][idx_tgt_posture]['calibration']['frozen'] = metrics['calibration']['frozen']
        results['repetition'][idx_repetition]['subject'][idx_subject]['day'][idx_day]['reference_posture'][idx_ref_posture][
            'target_posture'][idx_tgt_posture]['validation']['frozen'] = metrics['validation']['frozen']
        
        results['repetition'][idx_repetition]['subject'][idx_subject]['day'][idx_day]['reference_posture'][idx_ref_posture][
            'target_posture'][idx_tgt_posture]['calibration']['refit'] = metrics['calibration']['refit']
        results['repetition'][idx_repetition]['subject'][idx_subject]['day'][idx_day]['reference_posture'][idx_ref_posture][
            'target_posture'][idx_tgt_posture]['validation']['refit'] = metrics['validation']['refit']
        
        del metrics

        # ------------------------------------------------------------------- #
        
        # save to file
        # save the updated results dictionary after each validation
        results_outer_dict = {'results': results}
        Path(RESULTS_DIR_PATH).mkdir(parents=True, exist_ok=True)
        with open(RESULTS_FILE_FULLPATH, 'wb') as f:
            pickle.dump(results_outer_dict, f)
# Out:
# ------------------------------------------------------------------
# REPETITION	1/1
# SUBJECT	1/7
# DAY	1/8
# POSTURE	1/4 AS REFERENCE
# (all indices are one-based)
# ------------------------------------------------------------------
#
#
#
# 		TRAINING		VALIDATION
#
# EPOCH		Loss	Proxy		Loss	Proxy		Time (s)
#
# 1/4		1.6719	0.4530		none	none		0.1
# 2/4		1.5732	0.6079		none	none		0.0
# 3/4		1.4782	0.6300		none	none		0.0
# 4/4		1.3863	0.6696		none	none		0.0
#
# --------------------------------------------------------------
# TARGET POSTURE 1
# (trained on 1)
# --------------------------------------------------------------
#
#
# VALIDATION METRICS
# unbalanced
# 0.8103015075376885
# 0.5628140703517588
# balanced
# 0.6754893130907299
# 0.21790276607119144
#
# --------------------------------------------------------------
# TARGET POSTURE 2
# (trained on 1)
# --------------------------------------------------------------
#
#
# VALIDATION METRICS
# unbalanced
# 0.7321668909825033
# 0.7146702557200538
# balanced
# 0.5791463042609725
# 0.5763753223086525
#
# --------------------------------------------------------------
# TARGET POSTURE 3
# (trained on 1)
# --------------------------------------------------------------
#
#
# VALIDATION METRICS
# unbalanced
# 0.7486979166666666
# 0.5885416666666666
# balanced
# 0.6021775188199879
# 0.3685588895041814
#
# --------------------------------------------------------------
# TARGET POSTURE 4
# (trained on 1)
# --------------------------------------------------------------
#
#
# VALIDATION METRICS
# unbalanced
# 0.6611464968152866
# 0.6178343949044586
# balanced
# 0.47331459963038913
# 0.4113535100377206
#
# ------------------------------------------------------------------
# REPETITION	1/1
# SUBJECT	1/7
# DAY	1/8
# POSTURE	2/4 AS REFERENCE
# (all indices are one-based)
# ------------------------------------------------------------------
#
#
#
# 		TRAINING		VALIDATION
#
# EPOCH		Loss	Proxy		Loss	Proxy		Time (s)
#
# 1/4		1.6526	0.3060		none	none		0.0
# 2/4		1.5704	0.3274		none	none		0.0
# 3/4		1.4862	0.4620		none	none		0.0
# 4/4		1.3999	0.4897		none	none		0.0
#
# --------------------------------------------------------------
# TARGET POSTURE 1
# (trained on 2)
# --------------------------------------------------------------
#
#
# VALIDATION METRICS
# unbalanced
# 0.5979899497487438
# 0.10427135678391959
# balanced
# 0.3879150798008069
# 0.20686490809669558
#
# --------------------------------------------------------------
# TARGET POSTURE 2
# (trained on 2)
# --------------------------------------------------------------
#
#
# VALIDATION METRICS
# unbalanced
# 0.6325706594885598
# 0.6446837146702558
# balanced
# 0.4698914880832042
# 0.4881925674862573
#
# --------------------------------------------------------------
# TARGET POSTURE 3
# (trained on 2)
# --------------------------------------------------------------
#
#
# VALIDATION METRICS
# unbalanced
# 0.6380208333333334
# 0.16015625
# balanced
# 0.48561425340836095
# 0.29413705149612224
#
# --------------------------------------------------------------
# TARGET POSTURE 4
# (trained on 2)
# --------------------------------------------------------------
#
#
# VALIDATION METRICS
# unbalanced
# 0.5821656050955414
# 0.13503184713375796
# balanced
# 0.41797091683872584
# 0.19106491563651906
#
# ------------------------------------------------------------------
# REPETITION	1/1
# SUBJECT	1/7
# DAY	1/8
# POSTURE	3/4 AS REFERENCE
# (all indices are one-based)
# ------------------------------------------------------------------
#
#
#
# 		TRAINING		VALIDATION
#
# EPOCH		Loss	Proxy		Loss	Proxy		Time (s)
#
# 1/4		1.8990	0.1540		none	none		0.0
# 2/4		1.8096	0.1975		none	none		0.0
# 3/4		1.7306	0.3102		none	none		0.0
# 4/4		1.6566	0.3219		none	none		0.0
#
# --------------------------------------------------------------
# TARGET POSTURE 1
# (trained on 3)
# --------------------------------------------------------------
#
#
# VALIDATION METRICS
# unbalanced
# 0.15452261306532664
# 0.13190954773869346
# balanced
# 0.2735747438318239
# 0.23409348555193354
#
# --------------------------------------------------------------
# TARGET POSTURE 2
# (trained on 3)
# --------------------------------------------------------------
#
#
# VALIDATION METRICS
# unbalanced
# 0.2234185733512786
# 0.2274562584118439
# balanced
# 0.37192163647755755
# 0.3765503958760537
#
# --------------------------------------------------------------
# TARGET POSTURE 3
# (trained on 3)
# --------------------------------------------------------------
#
#
# VALIDATION METRICS
# unbalanced
# 0.18880208333333334
# 0.1953125
# balanced
# 0.32737569957225526
# 0.3582235078814681
#
# --------------------------------------------------------------
# TARGET POSTURE 4
# (trained on 3)
# --------------------------------------------------------------
#
#
# VALIDATION METRICS
# unbalanced
# 0.16560509554140126
# 0.12738853503184713
# balanced
# 0.2691917131329616
# 0.21462214968946913
#
# ------------------------------------------------------------------
# REPETITION	1/1
# SUBJECT	1/7
# DAY	1/8
# POSTURE	4/4 AS REFERENCE
# (all indices are one-based)
# ------------------------------------------------------------------
#
#
#
# 		TRAINING		VALIDATION
#
# EPOCH		Loss	Proxy		Loss	Proxy		Time (s)
#
# 1/4		1.7455	0.2491		none	none		0.0
# 2/4		1.6607	0.3094		none	none		0.0
# 3/4		1.5795	0.4727		none	none		0.0
# 4/4		1.4986	0.5086		none	none		0.0
#
# --------------------------------------------------------------
# TARGET POSTURE 1
# (trained on 4)
# --------------------------------------------------------------
#
#
# VALIDATION METRICS
# unbalanced
# 0.6984924623115578
# 0.6683417085427136
# balanced
# 0.4767276559635431
# 0.4560647897659782
#
# --------------------------------------------------------------
# TARGET POSTURE 2
# (trained on 4)
# --------------------------------------------------------------
#
#
# VALIDATION METRICS
# unbalanced
# 0.6837146702557201
# 0.6473755047106325
# balanced
# 0.5285240800865801
# 0.46850677931223705
#
# --------------------------------------------------------------
# TARGET POSTURE 3
# (trained on 4)
# --------------------------------------------------------------
#
#
# VALIDATION METRICS
# unbalanced
# 0.6809895833333334
# 0.6731770833333334
# balanced
# 0.48759965616262374
# 0.48062007323392103
#
# --------------------------------------------------------------
# TARGET POSTURE 4
# (trained on 4)
# --------------------------------------------------------------
#
#
# VALIDATION METRICS
# unbalanced
# 0.686624203821656
# 0.1159235668789809
# balanced
# 0.5303321434900382
# 0.16666666666666666
#
# ------------------------------------------------------------------
# REPETITION	1/1
# SUBJECT	1/7
# DAY	2/8
# POSTURE	1/4 AS REFERENCE
# (all indices are one-based)
# ------------------------------------------------------------------
#
#
#
# 		TRAINING		VALIDATION
#
# EPOCH		Loss	Proxy		Loss	Proxy		Time (s)
#
# 1/4		1
none	none		0.0
#
# --------------------------------------------------------------
# TARGET POSTURE 1
# (trained on 3)
# --------------------------------------------------------------
#
#
# VALIDATION METRICS
# unbalanced
# 0.1746031746031746
# 0.07830687830687831
# balanced
# 0.3762198706643151
# 0.16666666666666666
#
# --------------------------------------------------------------
# TARGET POSTURE 2
# (trained on 3)
# --------------------------------------------------------------
#
#
# VALIDATION METRICS
# unbalanced
# 0.19230769230769232
# 0.18212669683257918
# balanced
# 0.35521834172131567
# 0.33646452900208423
#
# --------------------------------------------------------------
# TARGET POSTURE 3
# (trained on 3)
# --------------------------------------------------------------
#
#
# VALIDATION METRICS
# unbalanced
# 0.24687144482366324
# 0.2036405005688282
# balanced
# 0.4574893115140793
# 0.38135412059560664
#
# --------------------------------------------------------------
# TARGET POSTURE 4
# (trained on 3)
# --------------------------------------------------------------
#
#
# VALIDATION METRICS
# unbalanced
# 0.23043478260869565
# 0.15869565217391304
# balanced
# 0.46873594242015293
# 0.32699805068226123
#
# ------------------------------------------------------------------
# REPETITION	1/1
# SUBJECT	1/7
# DAY	7/8
# POSTURE	4/4 AS REFERENCE
# (all indices are one-based)
# ------------------------------------------------------------------
#
#
#
# 		TRAINING		VALIDATION
#
# EPOCH		Loss	Proxy		Loss	Proxy		Time (s)
#
# 1/4		1.7104	0.1278		none	none		0.0
# 2/4		1.6060	0.2653		none	none		0.0
# 3/4		1.5037	0.3345		none	none		0.0
# 4/4		1.3960	0.5963		none	none		0.0
#
# --------------------------------------------------------------
# TARGET POSTURE 1
# (trained on 4)
# --------------------------------------------------------------
#
#
# VALIDATION METRICS
# unbalanced
# 0.8338624338624339
# 0.2105820105820106
# balanced
# 0.7382482106166317
# 0.4078111946532999
#
# --------------------------------------------------------------
# TARGET POSTURE 2
# (trained on 4)
# --------------------------------------------------------------
#
#
# VALIDATION METRICS
# unbalanced
# 0.7680995475113123
# 0.24773755656108598
# balanced
# 0.5983147039735913
# 0.45192628939148066
#
# --------------------------------------------------------------
# TARGET POSTURE 3
# (trained on 4)
# --------------------------------------------------------------
#
#
# VALIDATION METRICS
# unbalanced
# 0.70193401592719
# 0.24232081911262798
# balanced
# 0.6057065179445391
# 0.42510942671079316
#
# --------------------------------------------------------------
# TARGET POSTURE 4
# (trained on 4)
# --------------------------------------------------------------
#
#
# VALIDATION METRICS
# unbalanced
# 0.7315217391304348
# 0.7152173913043478
# balanced
# 0.5914631581884605
# 0.5348044940069717
#
# ------------------------------------------------------------------
# REPETITION	1/1
# SUBJECT	1/7
# DAY	8/8
# POSTURE	1/4 AS REFERENCE
# (all indices are one-based)
# ------------------------------------------------------------------
#
#
#
# 		TRAINING		VALIDATION
#
# EPOCH		Loss	Proxy		Loss	Proxy		Time (s)
#
# 1/4		2.0173	0.2808		none	none		0.0
# 2/4		1.9079	0.2868		none	none		0.0
# 3/4		1.8193	0.2903		none	none		0.0
# 4/4		1.7372	0.2892		none	none		0.0
#
# --------------------------------------------------------------
# TARGET POSTURE 1
# (trained on 1)
# --------------------------------------------------------------
#
#
# VALIDATION METRICS
# unbalanced
# 0.618096357226792
# 0.618096357226792
# balanced
# 0.30557841926823054
# 0.30557841926823054
#
# --------------------------------------------------------------
# TARGET POSTURE 2
# (trained on 1)
# --------------------------------------------------------------
#
#
# VALIDATION METRICS
# unbalanced
# 0.6631130063965884
# 0.7025586353944563
# balanced
# 0.3255585493852642
# 0.3983021483021483
#
# --------------------------------------------------------------
# TARGET POSTURE 3
# (trained on 1)
# --------------------------------------------------------------
#
#
# VALIDATION METRICS
# unbalanced
# 0.5821917808219178
# 0.6929223744292238
# balanced
# 0.1920642346439159
# 0.4060218960617367
#
# --------------------------------------------------------------
# TARGET POSTURE 4
# (trained on 1)
# --------------------------------------------------------------
#
#
# VALIDATION METRICS
# unbalanced
# 0.6247086247086248
# 0.6177156177156177
# balanced
# 0.2931906381988258
# 0.25915143953768444
#
# ------------------------------------------------------------------
# REPETITION	1/1
# SUBJECT	1/7
# DAY	8/8
# POSTURE	2/4 AS REFERENCE
# (all indices are one-based)
# ------------------------------------------------------------------
#
#
#
# 		TRAINING		VALIDATION
#
# EPOCH		Loss	Proxy		Loss	Proxy		Time (s)
#
# 1/4		1.6284	0.2942		none	none		0.0
# 2/4		1.5328	0.4201		none	none		0.0
# 3/4		1.4347	0.6631		none	none		0.0
# 4/4		1.3254	0.7361		none	none		0.0
#
# --------------------------------------------------------------
# TARGET POSTURE 1
# (trained on 2)
# --------------------------------------------------------------
#
#
# VALIDATION METRICS
# unbalanced
# 0.3384253819036428
# 0.24324324324324326
# balanced
# 0.6056408019761966
# 0.43843800705952507
#
# --------------------------------------------------------------
# TARGET POSTURE 2
# (trained on 2)
# --------------------------------------------------------------
#
#
# VALIDATION METRICS
# unbalanced
# 0.3486140724946695
# 0.27078891257995735
# balanced
# 0.7079343860181305
# 0.5516481945529247
#
# --------------------------------------------------------------
# TARGET POSTURE 3
# (trained on 2)
# --------------------------------------------------------------
#
#
# VALIDATION METRICS
# unbalanced
# 0.24315068493150685
# 0.1723744292237443
# balanced
# 0.46437981525030586
# 0.3334533290156005
#
# --------------------------------------------------------------
# TARGET POSTURE 4
# (trained on 2)
# --------------------------------------------------------------
#
#
# VALIDATION METRICS
# unbalanced
# 0.24358974358974358
# 0.11421911421911422
# balanced
# 0.4765670958830104
# 0.22888056809315185
#
# ------------------------------------------------------------------
# REPETITION	1/1
# SUBJECT	1/7
# DAY	8/8
# POSTURE	3/4 AS REFERENCE
# (all indices are one-based)
# ------------------------------------------------------------------
#
#
#
# 		TRAINING		VALIDATION
#
# EPOCH		Loss	Proxy		Loss	Proxy		Time (s)
#
# 1/4		1.6760	0.2059		none	none		0.0
# 2/4		1.5756	0.2591		none	none		0.0
# 3/4		1.4968	0.2994		none	none		0.0
# 4/4		1.4307	0.3419		none	none		0.0
#
# --------------------------------------------------------------
# TARGET POSTURE 1
# (trained on 3)
# --------------------------------------------------------------
#
#
# VALIDATION METRICS
# unbalanced
# 0.17508813160987075
# 0.21034077555816685
# balanced
# 0.30343834325972924
# 0.36643009508683894
#
# --------------------------------------------------------------
# TARGET POSTURE 2
# (trained on 3)
# --------------------------------------------------------------
#
#
# VALIDATION METRICS
# unbalanced
# 0.21002132196162046
# 0.16417910447761194
# balanced
# 0.4215522984676882
# 0.3275744098528908
#
# --------------------------------------------------------------
# TARGET POSTURE 3
# (trained on 3)
# --------------------------------------------------------------
#
#
# VALIDATION METRICS
# unbalanced
# 0.182648401826484
# 0.2226027397260274
# balanced
# 0.3444416619217416
# 0.4243677993677994
#
# --------------------------------------------------------------
# TARGET POSTURE 4
# (trained on 3)
# --------------------------------------------------------------
#
#
# VALIDATION METRICS
# unbalanced
# 0.21328671328671328
# 0.13636363636363635
# balanced
# 0.3971743236449119
# 0.25176485982517255
#
# ------------------------------------------------------------------
# REPETITION	1/1
# SUBJECT	1/7
# DAY	8/8
# POSTURE	4/4 AS REFERENCE
# (all indices are one-based)
# ------------------------------------------------------------------
#
#
#
# ...
# 0.33171602241528253
#
# --------------------------------------------------------------
# TARGET POSTURE 3
# (trained on 2)
# --------------------------------------------------------------
#
#
# VALIDATION METRICS
# unbalanced
# 0.12028301886792453
# 0.1474056603773585
# balanced
# 0.19436310276516336
# 0.2538859122808911
#
# --------------------------------------------------------------
# TARGET POSTURE 4
# (trained on 2)
# --------------------------------------------------------------
#
#
# VALIDATION METRICS
# unbalanced
# 0.11568409343715239
# 0.09899888765294772
# balanced
# 0.19185872018305491
# 0.19637447631383806
#
# ------------------------------------------------------------------
# REPETITION	1/1
# SUBJECT	7/7
# DAY	6/8
# POSTURE	3/4 AS REFERENCE
# (all indices are one-based)
# ------------------------------------------------------------------
#
#
#
# 		TRAINING		VALIDATION
#
# EPOCH		Loss	Proxy		Loss	Proxy		Time (s)
#
# 1/4		1.7397	0.1949		none	none		0.0
# 2/4		1.6673	0.2585		none	none		0.0
# 3/4		1.5978	0.3254		none	none		0.0
# 4/4		1.5255	0.4289		none	none		0.0
#
# --------------------------------------------------------------
# TARGET POSTURE 1
# (trained on 3)
# --------------------------------------------------------------
#
#
# VALIDATION METRICS
# unbalanced
# 0.2858707557502738
# 0.0700985761226725
# balanced
# 0.27377867123669425
# 0.1383711682557752
#
# --------------------------------------------------------------
# TARGET POSTURE 2
# (trained on 3)
# --------------------------------------------------------------
#
#
# VALIDATION METRICS
# unbalanced
# 0.28604118993135014
# 0.5491990846681922
# balanced
# 0.2585255840025912
# 0.4574634900089267
#
# --------------------------------------------------------------
# TARGET POSTURE 3
# (trained on 3)
# --------------------------------------------------------------
#
#
# VALIDATION METRICS
# unbalanced
# 0.36674528301886794
# 0.39504716981132076
# balanced
# 0.43892938918069224
# 0.49922747580044674
#
# --------------------------------------------------------------
# TARGET POSTURE 4
# (trained on 3)
# --------------------------------------------------------------
#
#
# VALIDATION METRICS
# unbalanced
# 0.3281423804226919
# 0.30589543937708563
# balanced
# 0.2577091273496595
# 0.37473456956662665
#
# ------------------------------------------------------------------
# REPETITION	1/1
# SUBJECT	7/7
# DAY	6/8
# POSTURE	4/4 AS REFERENCE
# (all indices are one-based)
# ------------------------------------------------------------------
#
#
#
# 		TRAINING		VALIDATION
#
# EPOCH		Loss	Proxy		Loss	Proxy		Time (s)
#
# 1/4		1.7587	0.2519		none	none		0.0
# 2/4		1.6848	0.3312		none	none		0.0
# 3/4		1.6119	0.3551		none	none		0.0
# 4/4		1.5390	0.3983		none	none		0.0
#
# --------------------------------------------------------------
# TARGET POSTURE 1
# (trained on 4)
# --------------------------------------------------------------
#
#
# VALIDATION METRICS
# unbalanced
# 0.23110624315443593
# 0.10076670317634173
# balanced
# 0.4684385382059801
# 0.18115942028985507
#
# --------------------------------------------------------------
# TARGET POSTURE 2
# (trained on 4)
# --------------------------------------------------------------
#
#
# VALIDATION METRICS
# unbalanced
# 0.20137299771167047
# 0.12242562929061784
# balanced
# 0.3642538818310143
# 0.23119104926247022
#
# --------------------------------------------------------------
# TARGET POSTURE 3
# (trained on 4)
# --------------------------------------------------------------
#
#
# VALIDATION METRICS
# unbalanced
# 0.23113207547169812
# 0.1650943396226415
# balanced
# 0.44313725490196076
# 0.31696375519904935
#
# --------------------------------------------------------------
# TARGET POSTURE 4
# (trained on 4)
# --------------------------------------------------------------
#
#
# VALIDATION METRICS
# unbalanced
# 0.20578420467185762
# 0.23025583982202447
# balanced
# 0.4008890462181968
# 0.4410771903698188
#
# ------------------------------------------------------------------
# REPETITION	1/1
# SUBJECT	7/7
# DAY	7/8
# POSTURE	1/4 AS REFERENCE
# (all indices are one-based)
# ------------------------------------------------------------------
#
#
#
# 		TRAINING		VALIDATION
#
# EPOCH		Loss	Proxy		Loss	Proxy		Time (s)
#
# 1/4		1.8234	0.2819		none	none		0.0
# 2/4		1.7030	0.2885		none	none		0.0
# 3/4		1.6055	0.3162		none	none		0.0
# 4/4		1.5094	0.4317		none	none		0.0
#
# --------------------------------------------------------------
# TARGET POSTURE 1
# (trained on 1)
# --------------------------------------------------------------
#
#
# VALIDATION METRICS
# unbalanced
# 0.21793416572077184
# 0.2122587968217934
# balanced
# 0.4303187546330616
# 0.4173461823573017
#
# --------------------------------------------------------------
# TARGET POSTURE 2
# (trained on 1)
# --------------------------------------------------------------
#
#
# VALIDATION METRICS
# unbalanced
# 0.17023675310033823
# 0.02818489289740699
# balanced
# 0.33717948717948715
# 0.0535042735042735
#
# --------------------------------------------------------------
# TARGET POSTURE 3
# (trained on 1)
# --------------------------------------------------------------
#
#
# VALIDATION METRICS
# unbalanced
# 0.08437856328392246
# 0.09236031927023945
# balanced
# 0.15854700854700854
# 0.17333333333333334
#
# --------------------------------------------------------------
# TARGET POSTURE 4
# (trained on 1)
# --------------------------------------------------------------
#
#
# VALIDATION METRICS
# unbalanced
# 0.034988713318284424
# 0.030474040632054177
# balanced
# 0.06778565002249212
# 0.058545134203028946
#
# ------------------------------------------------------------------
# REPETITION	1/1
# SUBJECT	7/7
# DAY	7/8
# POSTURE	2/4 AS REFERENCE
# (all indices are one-based)
# ------------------------------------------------------------------
#
#
#
# 		TRAINING		VALIDATION
#
# EPOCH		Loss	Proxy		Loss	Proxy		Time (s)
#
# 1/4		1.8626	0.1668		none	none		0.0
# 2/4		1.7354	0.2317		none	none		0.0
# 3/4		1.6239	0.3596		none	none		0.0
# 4/4		1.5163	0.5181		none	none		0.0
#
# --------------------------------------------------------------
# TARGET POSTURE 1
# (trained on 2)
# --------------------------------------------------------------
#
#
# VALIDATION METRICS
# unbalanced
# 0.1362088535754824
# 0.17480136208853575
# balanced
# 0.2465705545396005
# 0.3363179166284511
#
# --------------------------------------------------------------
# TARGET POSTURE 2
# (trained on 2)
# --------------------------------------------------------------
#
#
# VALIDATION METRICS
# unbalanced
# 0.27395715896279593
# 0.14543404735062007
# balanced
# 0.53362556556619
# 0.27734877734877733
#
# --------------------------------------------------------------
# TARGET POSTURE 3
# (trained on 2)
# --------------------------------------------------------------
#
#
# VALIDATION METRICS
# unbalanced
# 0.17217787913340935
# 0.08893956670467502
# balanced
# 0.31546665845446337
# 0.1756643672497331
#
# --------------------------------------------------------------
# TARGET POSTURE 4
# (trained on 2)
# --------------------------------------------------------------
#
#
# VALIDATION METRICS
# unbalanced
# 0.2618510158013544
# 0.08916478555304741
# balanced
# 0.46567756501495206
# 0.1810025458480836
#
# ------------------------------------------------------------------
# REPETITION	1/1
# SUBJECT	7/7
# DAY	7/8
# POSTURE	3/4 AS REFERENCE
# (all indices are one-based)
# ------------------------------------------------------------------
#
#
#
# 		TRAINING		VALIDATION
#
# EPOCH		Loss	Proxy		Loss	Proxy		Time (s)
#
# 1/4		1.7376	0.1722		none	none		0.0
# 2/4		1.6257	0.2395		none	none		0.0
# 3/4		1.5360	0.3529		none	none		0.0
# 4/4		1.4584	0.4265		none	none		0.0
#
# --------------------------------------------------------------
# TARGET POSTURE 1
# (trained on 3)
# --------------------------------------------------------------
#
#
# VALIDATION METRICS
# unbalanced
# 0.21793416572077184
# 0.1872871736662883
# balanced
# 0.41523175222005637
# 0.3583560366197875
#
# --------------------------------------------------------------
# TARGET POSTURE 2
# (trained on 3)
# --------------------------------------------------------------
#
#
# VALIDATION METRICS
# unbalanced
# 0.2638105975197294
# 0.673055242390079
# balanced
# 0.4930901885715245
# 0.4338878700371824
#
# --------------------------------------------------------------
# TARGET POSTURE 3
# (trained on 3)
# --------------------------------------------------------------
#
#
# VALIDATION METRICS
# unbalanced
# 0.23831242873432154
# 0.09007981755986318
# balanced
# 0.42929570880790396
# 0.15328671328671328
#
# --------------------------------------------------------------
# TARGET POSTURE 4
# (trained on 3)
# --------------------------------------------------------------
#
#
# VALIDATION METRICS
# unbalanced
# 0.23927765237020315
# 0.13882618510158012
# balanced
# 0.3101525290890456
# 0.1417004048582996
#
# ------------------------------------------------------------------
# REPETITION	1/1
# SUBJECT	7/7
# DAY	7/8
# POSTURE	4/4 AS REFERENCE
# (all indices are one-based)
# ------------------------------------------------------------------
#
#
#
# 		TRAINING		VALIDATION
#
# EPOCH		Loss	Proxy		Loss	Proxy		Time (s)
#
# 1/4		1.7109	0.2935		none	none		0.0
# 2/4		1.5910	0.3092		none	none		0.0
# 3/4		1.4796	0.3629		none	none		0.0
# 4/4		1.3709	0.5388		none	none		0.0
#
# --------------------------------------------------------------
# TARGET POSTURE 1
# (trained on 4)
# --------------------------------------------------------------
#
#
# VALIDATION METRICS
# unbalanced
# 0.699205448354143
# 0.7196367763904654
# balanced
# 0.42882272936614546
# 0.48862245788121966
#
# --------------------------------------------------------------
# TARGET POSTURE 2
# (trained on 4)
# --------------------------------------------------------------
#
#
# VALIDATION METRICS
# unbalanced
# 0.7857948139797069
# 0.7756482525366404
# balanced
# 0.5745321454358783
# 0.6290719107025591
#
# --------------------------------------------------------------
# TARGET POSTURE 3
# (trained on 4)
# --------------------------------------------------------------
#
#
# VALIDATION METRICS
# unbalanced
# 0.798175598631699
# 0.6282782212086659
# balanced
# 0.631471089885724
# 0.3351689187055041
#
# --------------------------------------------------------------
# TARGET POSTURE 4
# (trained on 4)
# --------------------------------------------------------------
#
#
# VALIDATION METRICS
# unbalanced
# 0.6636568848758465
# 0.5654627539503386
# balanced
# 0.4876434188195495
# 0.30756225460040126
#
# ------------------------------------------------------------------
# REPETITION	1/1
# SUBJECT	7/7
# DAY	8/8
# POSTURE	1/4 AS REFERENCE
# (all indices are one-based)
# ------------------------------------------------------------------
#
#
#
# 		TRAINING		VALIDATION
#
# EPOCH		Loss	Proxy		Loss	Proxy		Time (s)
#
# 1/4		1.7500	0.0978		none	none		0.0
# 2/4		1.6542	0.3322		none	none		0.0
# 3/4		1.5627	0.3701		none	none		0.0
# 4/4		1.4738	0.4022		none	none		0.0
#
# --------------------------------------------------------------
# TARGET POSTURE 1
# (trained on 1)
# --------------------------------------------------------------
#
#
# VALIDATION METRICS
# unbalanced
# 0.6871444823663254
# 0.6825938566552902
# balanced
# 0.4255542702911124
# 0.42453812247724737
#
# --------------------------------------------------------------
# TARGET POSTURE 2
# (trained on 1)
# --------------------------------------------------------------
#
#
# VALIDATION METRICS
# unbalanced
# 0.6433649289099526
# 0.02843601895734597
# balanced
# 0.3902346436503452
# 0.015819972843509163
#
# --------------------------------------------------------------
# TARGET POSTURE 3
# (trained on 1)
# --------------------------------------------------------------
#
#
# VALIDATION METRICS
# unbalanced
# 0.7731277533039648
# 0.6530837004405287
# balanced
# 0.569938169066076
# 0.32775009228497604
#
# --------------------------------------------------------------
# TARGET POSTURE 4
# (trained on 1)
# --------------------------------------------------------------
#
#
# VALIDATION METRICS
# unbalanced
# 0.660460021905805
# 0.033953997809419496
# balanced
# 0.3946072700661368
# 0.05505754012672311
#
# ------------------------------------------------------------------
# REPETITION	1/1
# SUBJECT	7/7
# DAY	8/8
# POSTURE	2/4 AS REFERENCE
# (all indices are one-based)
# ------------------------------------------------------------------
#
#
#
# 		TRAINING		VALIDATION
#
# EPOCH		Loss	Proxy		Loss	Proxy		Time (s)
#
# 1/4		1.7314	0.2058		none	none		0.0
# 2/4		1.6398	0.3024		none	none		0.0
# 3/4		1.5466	0.3784		none	none		0.0
# 4/4		1.4488	0.4152		none	none		0.0
#
# --------------------------------------------------------------
# TARGET POSTURE 1
# (trained on 2)
# --------------------------------------------------------------
#
#
# VALIDATION METRICS
# unbalanced
# 0.1080773606370876
# 0.149032992036405
# balanced
# 0.192959723133048
# 0.2662503523808392
#
# --------------------------------------------------------------
# TARGET POSTURE 2
# (trained on 2)
# --------------------------------------------------------------
#
#
# VALIDATION METRICS
# unbalanced
# 0.23104265402843602
# 0.10308056872037914
# balanced
# 0.4140355176940543
# 0.18773327983854302
#
# --------------------------------------------------------------
# TARGET POSTURE 3
# (trained on 2)
# --------------------------------------------------------------
#
#
# VALIDATION METRICS
# unbalanced
# 0.17841409691629956
# 0.08700440528634361
# balanced
# 0.3358599557966646
# 0.16666666666666666
#
# --------------------------------------------------------------
# TARGET POSTURE 4
# (trained on 2)
# --------------------------------------------------------------
#
#
# VALIDATION METRICS
# unbalanced
# 0.21905805038335158
# 0.10952902519167579
# balanced
# 0.42290492875321767
# 0.2057596150367235
#
# ------------------------------------------------------------------
# REPETITION	1/1
# SUBJECT	7/7
# DAY	8/8
# POSTURE	3/4 AS REFERENCE
# (all indices are one-based)
# ------------------------------------------------------------------
#
#
#
# 		TRAINING		VALIDATION
#
# EPOCH		Loss	Proxy		Loss	Proxy		Time (s)
#
# 1/4		1.5882	0.3198		none	none		0.0
# 2/4		1.4905	0.4675		none	none		0.0
# 3/4		1.3977	0.5619		none	none		0.0
# 4/4		1.3101	0.5946		none	none		0.0
#
# --------------------------------------------------------------
# TARGET POSTURE 1
# (trained on 3)
# --------------------------------------------------------------
#
#
# VALIDATION METRICS
# unbalanced
# 0.6575654152445961
# 0.6484641638225256
# balanced
# 0.45706865443707545
# 0.4754488043961728
#
# --------------------------------------------------------------
# TARGET POSTURE 2
# (trained on 3)
# --------------------------------------------------------------
#
#
# VALIDATION METRICS
# unbalanced
# 0.6409952606635071
# 0.04028436018957346
# balanced
# 0.47118411455334175
# 0.06910569105691057
#
# --------------------------------------------------------------
# TARGET POSTURE 3
# (trained on 3)
# --------------------------------------------------------------
#
#
# VALIDATION METRICS
# unbalanced
# 0.7533039647577092
# 0.5925110132158591
# balanced
# 0.6087053936479901
# 0.42377719486381543
#
# --------------------------------------------------------------
# TARGET POSTURE 4
# (trained on 3)
# --------------------------------------------------------------
#
#
# VALIDATION METRICS
# unbalanced
# 0.6352683461117196
# 0.1774370208105148
# balanced
# 0.44276861496913583
# 0.32822113369302125
#
# ------------------------------------------------------------------
# REPETITION	1/1
# SUBJECT	7/7
# DAY	8/8
# POSTURE	4/4 AS REFERENCE
# (all indices are one-based)
# ------------------------------------------------------------------
#
#
#
# 		TRAINING		VALIDATION
#
# EPOCH		Loss	Proxy		Loss	Proxy		Time (s)
#
# 1/4		1.7715	0.2089		none	none		0.0
# 2/4		1.6501	0.3466		none	none		0.0
# 3/4		1.5367	0.5044		none	none		0.0
# 4/4		1.4269	0.5211		none	none		0.0
#
# --------------------------------------------------------------
# TARGET POSTURE 1
# (trained on 4)
# --------------------------------------------------------------
#
#
# VALIDATION METRICS
# unbalanced
# 0.7053469852104665
# 0.36291240045506257
# balanced
# 0.5718794606626636
# 0.47868075490847284
#
# --------------------------------------------------------------
# TARGET POSTURE 2
# (trained on 4)
# --------------------------------------------------------------
#
#
# VALIDATION METRICS
# unbalanced
# 0.7334123222748815
# 0.15758293838862558
# balanced
# 0.6349086688922309
# 0.27159536240499044
#
# --------------------------------------------------------------
# TARGET POSTURE 3
# (trained on 4)
# --------------------------------------------------------------
#
#
# VALIDATION METRICS
# unbalanced
# 0.7533039647577092
# 0.6299559471365639
# balanced
# 0.6236249538575119
# 0.4788805832410484
#
# --------------------------------------------------------------
# TARGET POSTURE 4
# (trained on 4)
# --------------------------------------------------------------
#
#
# VALIDATION METRICS
# unbalanced
# 0.6801752464403067
# 0.6582694414019715
# balanced
# 0.5297252786997704
# 0.4878073940931622
